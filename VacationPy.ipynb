# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID     City Country                 Date    Lat     Lng  Max Temp  \
# 0        0  Iqaluit      CA  2020-08-28 23:55:56  63.75  -68.51     48.20
# 1        1  Rikitea      PF  2020-08-28 23:55:56 -23.12 -134.97     69.28
# 2        2   Rorvik      NO  2020-08-28 23:55:57  64.86   11.24     53.10
# 3        3  Mataura      NZ  2020-08-28 23:51:59 -46.19  168.86     45.00
# 4        4   Pitogo      PH  2020-08-28 23:55:57  13.78  122.09     83.43
#
#    Humidity  Cloudiness  Wind Speed
# 0        66          75        5.82
# 1        66           0        5.77
# 2        66          32       11.97
# 3        72          35       11.01
# 4        77          96       10.47

# %%
# Get the data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# # CREATE HEATMAP

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variab;e
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.6)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## Create a Percent Humidity Heatmap

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## Create a Percent Cloudiness Heatmap

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ## Create a Wind Speed Heatmap

# %%
# Heatmap of percent Wind Speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Imput minimum and maximum temperature values and convert these values to floating-point decimals.

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip?"))
max_temp = float(input("What is the maximum temperature you would like for your trip?"))
# Out:
# What is the minimum temperature you would like for your trip?75
# What is the maximum temperature you would like for your trip?90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                        (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head()
# Out:
#     City_ID      City Country                 Date    Lat     Lng  Max Temp  \
# 4         4    Pitogo      PH  2020-08-28 23:55:57  13.78  122.09     83.43
# 11       11  Victoria      HK  2020-08-28 23:55:58  22.29  114.16     86.00
# 14       14    Atuona      PF  2020-08-28 23:55:59  -9.80 -139.03     78.06
# 18       18     Vaini      TO  2020-08-28 23:52:02 -21.20 -175.20     78.80
# 28       28  Celestun      MX  2020-08-28 23:56:01  20.87  -90.40     85.05
#
#     Humidity  Cloudiness  Wind Speed
# 4         77          96       10.47
# 11        79          60        3.89
# 14        79          63       21.59
# 18        74          75       11.41
# 28        78          78       10.31

# %%
preferred_cities_df.count()
# Out:
# City_ID       184
# City          184
# Country       184
# Date          184
# Lat           184
# Lng           184
# Max Temp      184
# Humidity      184
# Cloudiness    184
# Wind Speed    184
# dtype: int64

# %% [markdown]
# ## Get Travel Destinations

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng", ]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#           City Country  Max Temp    Lat     Lng Hotel Name
# 4       Pitogo      PH     83.43  13.78  122.09
# 11    Victoria      HK     86.00  22.29  114.16
# 14      Atuona      PF     78.06  -9.80 -139.03
# 18       Vaini      TO     78.80 -21.20 -175.20
# 28    Celestun      MX     85.05  20.87  -90.40
# 32  Butaritari      KI     82.27   3.07  172.79
# 33        Naze      JP     86.00  28.37  129.48
# 40    Hamilton      US     80.01  39.18  -84.53
# 41      Kampot      KH     84.20  10.62  104.18
# 44     Awjilah      LY     77.67  29.11   21.29

# %% [markdown]
# ## Retrieve Hotels from a Nearby Search

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHwEAABdMAO3Jxvg0aD6VvjKviujk2GHFUhuBR2nffL3UnT4hdt3VOvM0x_s4kpLK2PrCjYmmb6kGrVRC_SKGSruHSf9qJKURbwM66Iove8F28-NOOyRXdmqoT0VhrjO4EMdkqN1I_mPX0VpnZU_8o6rGBnyJRUsuKylCZ-TlmiaXav6lbkn76SXKYz-v-3S4Xy7TNPB5sNG8H2AiljzD1Xv9hU389iUl6ZahYtiQ4I7qAj_tXAtlOzAqYZfyu0jVpcN7rS8IJczoKAWk8gB0so6gyGaDfGQ5iztlV3gZ34j9cQBx20kMLl3j1tzeS-7bNnNaa_HzF0HkUgEpCAgCjVTVCa7Zgqn_paQ7mhZ2DToA1-SRuQJTDVLkTC0ck7O-y5aU_RIQKgr6dQmGpRdMlcR7hQwjHRoUBvKD3qY9ELSntu6eNRC3Q4i9uSg',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3914483, 'lng': 121.3852157},
#     'viewport': {'northeast': {'lat': 28.3928088302915,
#       'lng': 121.3869860802915},
#      'southwest': {'lat': 28.3901108697085, 'lng': 121.3842881197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hanting Express Wenling Wanchang North Road',
#    'place_id': 'ChIJbyNle8TMTzQRbJkfOyytAvY',
#    'reference': 'ChIJbyNle8TMTzQRbJkfOyytAvY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Jiulonghui Commercial Street, Wenling, 温岭'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.36751, 'lng': 121.36346},
#     'viewport': {'northeast': {'lat': 28.3688713302915,
#       'lng': 121.3648536802915},
#      'southwest': {'lat': 28.36617336970849, 'lng': 121.3621557197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Wenling Hotel',
#    'place_id': 'ChIJE7s0_XzMTzQR4Bim-3e0KS0',
#    'plus_code': {'compound_code': '9997+29 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW39997+29'},
#    'reference': 'ChIJE7s0_XzMTzQR4Bim-3e0KS0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '151 Beimen Street, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.37845, 'lng': 121.37563},
#     'viewport': {'northeast': {'lat': 28.3797679802915,
#       'lng': 121.3769449802915},
#      'southwest': {'lat': 28.37707001970849, 'lng': 121.3742470197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Century Dawn International Hotel',
#    'place_id': 'ChIJM_LLvZLMTzQRD_jsLk9C3s0',
#    'plus_code': {'compound_code': '99HG+97 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399HG+97'},
#    'reference': 'ChIJM_LLvZLMTzQRD_jsLk9C3s0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '502 Zhonghua Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3849926, 'lng': 121.3855546},
#     'viewport': {'northeast': {'lat': 28.3862915802915,
#       'lng': 121.3868880802915},
#      'southwest': {'lat': 28.3835936197085, 'lng': 121.3841901197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hawaii Oriental Hotel',
#    'place_id': 'ChIJQ5GrLOjMTzQRI9haEypDscI',
#    'plus_code': {'compound_code': '99MP+X6 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399MP+X6'},
#    'reference': 'ChIJQ5GrLOjMTzQRI9haEypDscI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '98 Henghu Middle Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.386432, 'lng': 121.365169},
#     'viewport': {'northeast': {'lat': 28.38784393029151,
#       'lng': 121.3665892802915},
#      'southwest': {'lat': 28.3851459697085, 'lng': 121.3638913197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': '七星云顶酒店',
#    'place_id': 'ChIJKzJT7PLMTzQRJb3YoKeVCqQ',
#    'plus_code': {'compound_code': '99P8+H3 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399P8+H3'},
#    'reference': 'ChIJKzJT7PLMTzQRJb3YoKeVCqQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '599 Zhonghua Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3750321, 'lng': 121.3780683},
#     'viewport': {'northeast': {'lat': 28.37638138029151,
#       'lng': 121.3794683302915},
#      'southwest': {'lat': 28.3736834197085, 'lng': 121.3767703697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': '锐思特汽车酒店',
#    'place_id': 'ChIJ-UUo2_LMTzQRcMULppS7Q3o',
#    'plus_code': {'compound_code': '99GH+26 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399GH+26'},
#    'reference': 'ChIJ-UUo2_LMTzQRcMULppS7Q3o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '温岭大厦, Sanxing Avenue, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.367655, 'lng': 121.365699},
#     'viewport': {'northeast': {'lat': 28.3688647802915,
#       'lng': 121.3671473802915},
#      'southwest': {'lat': 28.3661668197085, 'lng': 121.3644494197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Zhengchao International Hotel',
#    'place_id': 'ChIJL1uX0mLMTzQRYdpRnfZMg9A',
#    'plus_code': {'compound_code': '9998+37 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW39998+37'},
#    'rating': 3,
#    'reference': 'ChIJL1uX0mLMTzQRYdpRnfZMg9A',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '268 Wanshou Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3686379, 'lng': 121.369246},
#     'viewport': {'northeast': {'lat': 28.3700280302915,
#       'lng': 121.3705748302915},
#      'southwest': {'lat': 28.36733006970849, 'lng': 121.3678768697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': '锐思特汽车酒店',
#    'place_id': 'ChIJaZEOd2LMTzQRfucGKmXz340',
#    'plus_code': {'compound_code': '9999+FM Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW39999+FM'},
#    'reference': 'ChIJaZEOd2LMTzQRfucGKmXz340',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '199 Wanshou Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3761826, 'lng': 121.3773685},
#     'viewport': {'northeast': {'lat': 28.3775646802915,
#       'lng': 121.3787518302915},
#      'southwest': {'lat': 28.3748667197085, 'lng': 121.3760538697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bayview Holiday Inn',
#    'place_id': 'ChIJMchGtPLMTzQRGtLR7qYT_jQ',
#    'plus_code': {'compound_code': '99GG+FW Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399GG+FW'},
#    'reference': 'ChIJMchGtPLMTzQRGtLR7qYT_jQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '385 Zhonghua Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.369173, 'lng': 121.36501},
#     'viewport': {'northeast': {'lat': 28.3704695302915,
#       'lng': 121.3663822802915},
#      'southwest': {'lat': 28.36777156970849, 'lng': 121.3636843197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': '新海竽宾馆',
#    'place_id': 'ChIJUW_YT33MTzQRL5UzoAAgkuU',
#    'plus_code': {'compound_code': '9998+M2 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW39998+M2'},
#    'reference': 'ChIJUW_YT33MTzQRL5UzoAAgkuU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '鸣远路312号, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.369067, 'lng': 121.3641066},
#     'viewport': {'northeast': {'lat': 28.3704159302915,
#       'lng': 121.3655066302915},
#      'southwest': {'lat': 28.3677179697085, 'lng': 121.3628086697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Wu Jiao Chang Hotel',
#    'place_id': 'ChIJoR8ian3MTzQRV5k_rPWeF2A',
#    'plus_code': {'compound_code': '9997+JJ Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW39997+JJ'},
#    'reference': 'ChIJoR8ian3MTzQRV5k_rPWeF2A',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '9 Beishan Road, Wenling'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3704621, 'lng': 121.3740276},
#     'viewport': {'northeast': {'lat': 28.3718531802915,
#       'lng': 121.3753555302915},
#      'southwest': {'lat': 28.3691552197085, 'lng': 121.3726575697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Huatian Hotel',
#    'place_id': 'ChIJ2VVHqovMTzQR_Fuwn5iFjjo',
#    'plus_code': {'compound_code': '99CF+5J Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399CF+5J'},
#    'reference': 'ChIJ2VVHqovMTzQR_Fuwn5iFjjo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '39 Wanshou Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3691415, 'lng': 121.364989},
#     'viewport': {'northeast': {'lat': 28.3704485802915,
#       'lng': 121.3663565802915},
#      'southwest': {'lat': 28.3677506197085, 'lng': 121.3636586197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Xinhaiyu Hotel',
#    'place_id': 'ChIJ_58RUH3MTzQRe0d30hKvhPU',
#    'plus_code': {'compound_code': '9997+MX Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW39997+MX'},
#    'reference': 'ChIJ_58RUH3MTzQRe0d30hKvhPU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Mingyuan Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3687441, 'lng': 121.3763495},
#     'viewport': {'northeast': {'lat': 28.3701356302915,
#       'lng': 121.3776821302915},
#      'southwest': {'lat': 28.3674376697085, 'lng': 121.3749841697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Dongfang Hotel',
#    'place_id': 'ChIJN-Npz4rMTzQRphEzk4osODM',
#    'plus_code': {'compound_code': '999G+FG Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW3999G+FG'},
#    'reference': 'ChIJN-Npz4rMTzQRphEzk4osODM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Daheshan Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.366724, 'lng': 121.376441},
#     'viewport': {'northeast': {'lat': 28.3681589302915,
#       'lng': 121.3777536802915},
#      'southwest': {'lat': 28.3654609697085, 'lng': 121.3750557197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Huating Hotel',
#    'place_id': 'ChIJM1QaA2DMTzQRukvVAejRU1U',
#    'plus_code': {'compound_code': '998G+MH Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW3998G+MH'},
#    'reference': 'ChIJM1QaA2DMTzQRukvVAejRU1U',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '2 瓦屿山路, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.382673, 'lng': 121.37808},
#     'viewport': {'northeast': {'lat': 28.38398443029151,
#       'lng': 121.3793958802915},
#      'southwest': {'lat': 28.3812864697085, 'lng': 121.3766979197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Jinmao Business Hotel',
#    'place_id': 'ChIJw22EXOvMTzQRphzAOOT---k',
#    'plus_code': {'compound_code': '99MH+36 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399MH+36'},
#    'reference': 'ChIJw22EXOvMTzQRphzAOOT---k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '锦屏北路, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.389532, 'lng': 121.386121},
#     'viewport': {'northeast': {'lat': 28.3908801302915,
#       'lng': 121.3874429802915},
#      'southwest': {'lat': 28.3881821697085, 'lng': 121.3847450197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': '雷迪森大酒店',
#    'place_id': 'ChIJp1YHc8PMTzQRtBvoVyzHm3g',
#    'plus_code': {'compound_code': '99QP+RC Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399QP+RC'},
#    'reference': 'ChIJp1YHc8PMTzQRtBvoVyzHm3g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '新烟草大楼, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3934295, 'lng': 121.3846181},
#     'viewport': {'northeast': {'lat': 28.3947680302915,
#       'lng': 121.3859172302915},
#      'southwest': {'lat': 28.3920700697085, 'lng': 121.3832192697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Portman Garden Hotel',
#    'place_id': 'ChIJRxZMTMTMTzQRd4PweyHiNzQ',
#    'plus_code': {'compound_code': '99VM+9R Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399VM+9R'},
#    'reference': 'ChIJRxZMTMTMTzQRd4PweyHiNzQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '九龙汇商业街, Jiulonghui Commercial Pedestrian Street, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3980931, 'lng': 121.3811402},
#     'viewport': {'northeast': {'lat': 28.3994638802915,
#       'lng': 121.3825349302915},
#      'southwest': {'lat': 28.3967659197085, 'lng': 121.3798369697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Binhuang Zunrong Hotel',
#    'place_id': 'ChIJCXfdlsjMTzQRz6W3X9OavVA',
#    'plus_code': {'compound_code': '99XJ+6F Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399XJ+6F'},
#    'reference': 'ChIJCXfdlsjMTzQRz6W3X9OavVA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '万昌北路, Wanchang Middle Road, Wenling, Taizhou'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 28.3964338, 'lng': 121.3881602},
#     'viewport': {'northeast': {'lat': 28.3976701302915,
#       'lng': 121.3895449802915},
#      'southwest': {'lat': 28.3949721697085, 'lng': 121.3868470197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': '铜锣湾假日酒店',
#    'photos': [{'height': 920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102304313365498970113">周育军</a>'],
#      'photo_reference': 'CkQ0AAAAcAcuN44xgcydbUDoLdameI64UrTPeKRrSdY4ctmyMLe4KYY0486qS9ZviuW5LnJGV0SfcxKIDhhKK0MwnapVMxIQ-TbWm-Y2A6DwAFuTgtnt7RoUkIDmnxwgSHT5n8Niq3KciZCMLRk',
#      'width': 1632}],
#    'place_id': 'ChIJRzNlHtDMTzQRvTxrA8lQwzw',
#    'plus_code': {'compound_code': '99WQ+H7 Wenling, Taizhou, Zhejiang, China',
#     'global_code': '7QW399WQ+H7'},
#    'reference': 'ChIJRzNlHtDMTzQRvTxrA8lQwzw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '355 Shuguang East Road, Wenling, Taizhou'}],
#  'status': 'OK'}

# %%
hotel_df.head(10)
# Out:
#           City Country  Max Temp    Lat     Lng                 Hotel Name
# 4       Pitogo      PH     83.43  13.78  122.09                  Ricronald
# 11    Victoria      HK     86.00  22.29  114.16         Mini Hotel Central
# 14      Atuona      PF     78.06  -9.80 -139.03                Villa Enata
# 18       Vaini      TO     78.80 -21.20 -175.20        Keleti Beach Resort
# 28    Celestun      MX     85.05  20.87  -90.40               Posada Lilia
# 32  Butaritari      KI     82.27   3.07  172.79         Isles Sunset Lodge
# 33        Naze      JP     86.00  28.37  129.48                奄美ポートタワーホテル
# 40    Hamilton      US     80.01  39.18  -84.53  Six Acres Bed & Breakfast
# 41      Kampot      KH     84.20  10.62  104.18               Champa Lodge
# 44     Awjilah      LY     77.67  29.11   21.29

# %% [markdown]
# ## Create a Maximum Temperature Heatmap from a Hotel DataFrame

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
