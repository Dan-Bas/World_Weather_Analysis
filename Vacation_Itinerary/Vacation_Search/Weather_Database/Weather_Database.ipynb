# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.0000, high=90.0000, size=2000)
lngs = np.random.uniform(low=-180.0000, high=180.0000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
from citipy import citipy

cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Perform an API call with the OpenWeatherMap
import requests
# Import the API key
from config import weather_api_key

# Build basic URL + API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eba3522468d0a8ca6a2240c33ed79c78"

# %%
# Retrieve the following information from the API call
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | tigzirt
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | meulaboh
# Processing Record 6 of Set 1 | nome
# Processing Record 7 of Set 1 | zheleznodorozhnyy
# Processing Record 8 of Set 1 | port lincoln
# Processing Record 9 of Set 1 | klaksvik
# Processing Record 10 of Set 1 | korla
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | vardo
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | labuhan
# Processing Record 21 of Set 1 | alofi
# Processing Record 22 of Set 1 | emporia
# Processing Record 23 of Set 1 | tabou
# Processing Record 24 of Set 1 | touros
# Processing Record 25 of Set 1 | faya
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | yulara
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | nyurba
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | antofagasta
# Processing Record 36 of Set 1 | lasa
# Processing Record 37 of Set 1 | phangnga
# Processing Record 38 of Set 1 | tulun
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | pakokku
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | nouakchott
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | umm lajj
# Processing Record 46 of Set 1 | teguldet
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | sumkino
# Processing Record 50 of Set 1 | hasaki
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | orguz
# Processing Record 3 of Set 2 | dakar
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | vostok
# Processing Record 6 of Set 2 | cayenne
# Processing Record 7 of Set 2 | coihaique
# Processing Record 8 of Set 2 | kamaishi
# Processing Record 9 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 2 | muros
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | acari
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | erzin
# Processing Record 19 of Set 2 | jaru
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | porto novo
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | tabas
# Processing Record 24 of Set 2 | tarangnan
# Processing Record 25 of Set 2 | aksu
# Processing Record 26 of Set 2 | lavrentiya
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | jiangyou
# Processing Record 31 of Set 2 | belaya gora
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 2 | vao
# Processing Record 36 of Set 2 | san policarpo
# Processing Record 37 of Set 2 | tevaitoa
# Processing Record 38 of Set 2 | namatanai
# Processing Record 39 of Set 2 | grand gaube
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | teya
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | jalu
# Processing Record 48 of Set 2 | esperantinopolis
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | port hardy
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | sao filipe
# Processing Record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 3 | cortes
# Processing Record 6 of Set 3 | san quintin
# Processing Record 7 of Set 3 | kyren
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | haimen
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | songea
# Processing Record 13 of Set 3 | karoi
# Processing Record 14 of Set 3 | pavilosta
# Processing Record 15 of Set 3 | leh
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | axim
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | manzil jamil
# City not found. Skipping...
# Processing Record 21 of Set 3 | padang
# Processing Record 22 of Set 3 | igarka
# Processing Record 23 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | yumen
# Processing Record 25 of Set 3 | samarai
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | beisfjord
# Processing Record 28 of Set 3 | bilma
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | ramhormoz
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | keuruu
# Processing Record 33 of Set 3 | ayan
# Processing Record 34 of Set 3 | caloundra
# Processing Record 35 of Set 3 | tezu
# Processing Record 36 of Set 3 | mitha tiwana
# Processing Record 37 of Set 3 | katsuura
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | roald
# Processing Record 40 of Set 3 | arlit
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | luau
# Processing Record 43 of Set 3 | lunca de jos
# Processing Record 44 of Set 3 | plainview
# Processing Record 45 of Set 3 | kungurtug
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | kholmogory
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | husavik
# Processing Record 1 of Set 4 | mana
# Processing Record 2 of Set 4 | tommot
# Processing Record 3 of Set 4 | keffi
# Processing Record 4 of Set 4 | preobrazheniye
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 4 | mufulira
# Processing Record 7 of Set 4 | emerald
# Processing Record 8 of Set 4 | caravelas
# Processing Record 9 of Set 4 | oktyabrskoye
# Processing Record 10 of Set 4 | wabana
# Processing Record 11 of Set 4 | valparaiso
# Processing Record 12 of Set 4 | filadelfia
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | lebu
# Processing Record 15 of Set 4 | henties bay
# Processing Record 16 of Set 4 | kwinana
# Processing Record 17 of Set 4 | butaritari
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | lahad datu
# Processing Record 20 of Set 4 | zyryanka
# Processing Record 21 of Set 4 | santa maria
# Processing Record 22 of Set 4 | svetlyy
# Processing Record 23 of Set 4 | christchurch
# Processing Record 24 of Set 4 | shingu
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | port macquarie
# Processing Record 27 of Set 4 | rio gallegos
# Processing Record 28 of Set 4 | aljezur
# Processing Record 29 of Set 4 | dores do indaia
# Processing Record 30 of Set 4 | mahebourg
# Processing Record 31 of Set 4 | hauterive
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | malpe
# Processing Record 34 of Set 4 | cravo norte
# Processing Record 35 of Set 4 | ust-omchug
# Processing Record 36 of Set 4 | sorland
# Processing Record 37 of Set 4 | neiafu
# Processing Record 38 of Set 4 | mao
# Processing Record 39 of Set 4 | kilindoni
# Processing Record 40 of Set 4 | richards bay
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | luderitz
# Processing Record 43 of Set 4 | north bend
# Processing Record 44 of Set 4 | ouallam
# Processing Record 45 of Set 4 | suntar
# Processing Record 46 of Set 4 | paita
# Processing Record 47 of Set 4 | xuddur
# Processing Record 48 of Set 4 | beringovskiy
# Processing Record 49 of Set 4 | cadiz
# Processing Record 50 of Set 4 | svetlaya
# Processing Record 1 of Set 5 | asau
# Processing Record 2 of Set 5 | jalingo
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | dingle
# Processing Record 5 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 5 | russell
# Processing Record 7 of Set 5 | saint-philippe
# Processing Record 8 of Set 5 | sawakin
# Processing Record 9 of Set 5 | kalabo
# Processing Record 10 of Set 5 | madisonville
# Processing Record 11 of Set 5 | lorengau
# Processing Record 12 of Set 5 | hofn
# Processing Record 13 of Set 5 | kralendijk
# Processing Record 14 of Set 5 | zhucheng
# Processing Record 15 of Set 5 | vestmanna
# Processing Record 16 of Set 5 | sinnamary
# Processing Record 17 of Set 5 | port augusta
# Processing Record 18 of Set 5 | farafangana
# Processing Record 19 of Set 5 | abancay
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | jizan
# Processing Record 22 of Set 5 | ca mau
# Processing Record 23 of Set 5 | malabo
# Processing Record 24 of Set 5 | cahors
# Processing Record 25 of Set 5 | ye
# City not found. Skipping...
# Processing Record 26 of Set 5 | chuy
# Processing Record 27 of Set 5 | inhambane
# Processing Record 28 of Set 5 | vagay
# Processing Record 29 of Set 5 | tacoronte
# Processing Record 30 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 5 | surop
# City not found. Skipping...
# Processing Record 32 of Set 5 | payakumbuh
# Processing Record 33 of Set 5 | nanortalik
# Processing Record 34 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 5 | kahului
# Processing Record 36 of Set 5 | dandong
# Processing Record 37 of Set 5 | dukhovnitskoye
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 41 of Set 5 | bandrele
# Processing Record 42 of Set 5 | tautira
# Processing Record 43 of Set 5 | hirara
# Processing Record 44 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 5 | sideropolis
# Processing Record 46 of Set 5 | buala
# Processing Record 47 of Set 5 | ewa beach
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | ancud
# Processing Record 50 of Set 5 | coxim
# Processing Record 1 of Set 6 | midleton
# Processing Record 2 of Set 6 | alta floresta
# Processing Record 3 of Set 6 | severo-kurilsk
# Processing Record 4 of Set 6 | broome
# Processing Record 5 of Set 6 | pringsewu
# Processing Record 6 of Set 6 | betioky
# Processing Record 7 of Set 6 | baruun-urt
# Processing Record 8 of Set 6 | itarema
# Processing Record 9 of Set 6 | moranbah
# Processing Record 10 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 6 | coquimbo
# Processing Record 12 of Set 6 | tilichiki
# Processing Record 13 of Set 6 | treinta y tres
# Processing Record 14 of Set 6 | hondo
# Processing Record 15 of Set 6 | puebloviejo
# Processing Record 16 of Set 6 | elk point
# Processing Record 17 of Set 6 | labe
# Processing Record 18 of Set 6 | namibe
# Processing Record 19 of Set 6 | bambous virieux
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 6 | bom jesus
# Processing Record 23 of Set 6 | porto santo
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 6 | mayumba
# Processing Record 27 of Set 6 | vanavara
# Processing Record 28 of Set 6 | kemijarvi
# Processing Record 29 of Set 6 | goedereede
# Processing Record 30 of Set 6 | iranshahr
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | lulea
# Processing Record 33 of Set 6 | alexandria
# Processing Record 34 of Set 6 | jatai
# Processing Record 35 of Set 6 | pontian kecil
# Processing Record 36 of Set 6 | jiuquan
# Processing Record 37 of Set 6 | antsohihy
# Processing Record 38 of Set 6 | kaka
# Processing Record 39 of Set 6 | wahiawa
# Processing Record 40 of Set 6 | shubarkuduk
# Processing Record 41 of Set 6 | alice springs
# Processing Record 42 of Set 6 | narsaq
# Processing Record 43 of Set 6 | santa cruz
# Processing Record 44 of Set 6 | tutoia
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | pandan
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | aktash
# Processing Record 49 of Set 6 | invermere
# Processing Record 50 of Set 6 | saint-joseph
# Processing Record 1 of Set 7 | bonavista
# Processing Record 2 of Set 7 | vanimo
# Processing Record 3 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 4 of Set 7 | babu
# Processing Record 5 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 6 of Set 7 | kenai
# Processing Record 7 of Set 7 | kastamonu
# Processing Record 8 of Set 7 | saint-augustin
# Processing Record 9 of Set 7 | komsomolskiy
# Processing Record 10 of Set 7 | taylorville
# Processing Record 11 of Set 7 | robertson
# Processing Record 12 of Set 7 | hokitika
# Processing Record 13 of Set 7 | oistins
# Processing Record 14 of Set 7 | victoria
# Processing Record 15 of Set 7 | fethiye
# Processing Record 16 of Set 7 | maceio
# Processing Record 17 of Set 7 | geraldton
# Processing Record 18 of Set 7 | mushie
# Processing Record 19 of Set 7 | manoel urbano
# Processing Record 20 of Set 7 | tongchuan
# Processing Record 21 of Set 7 | ahipara
# Processing Record 22 of Set 7 | drjanovo
# City not found. Skipping...
# Processing Record 23 of Set 7 | salisbury
# Processing Record 24 of Set 7 | auki
# Processing Record 25 of Set 7 | pacific grove
# Processing Record 26 of Set 7 | mount abu
# Processing Record 27 of Set 7 | cairo
# Processing Record 28 of Set 7 | portland
# Processing Record 29 of Set 7 | san antonio
# Processing Record 30 of Set 7 | miles city
# Processing Record 31 of Set 7 | sambava
# Processing Record 32 of Set 7 | mareeba
# Processing Record 33 of Set 7 | aguascalientes
# Processing Record 34 of Set 7 | pinawa
# Processing Record 35 of Set 7 | vallenar
# Processing Record 36 of Set 7 | haines junction
# Processing Record 37 of Set 7 | placido de castro
# Processing Record 38 of Set 7 | raudeberg
# Processing Record 39 of Set 7 | mitsamiouli
# Processing Record 40 of Set 7 | sakakah
# Processing Record 41 of Set 7 | high rock
# Processing Record 42 of Set 7 | general pico
# Processing Record 43 of Set 7 | indianola
# Processing Record 44 of Set 7 | yar-sale
# Processing Record 45 of Set 7 | calama
# Processing Record 46 of Set 7 | ostrovnoy
# Processing Record 47 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 48 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 49 of Set 7 | borogontsy
# Processing Record 50 of Set 7 | vila velha
# Processing Record 1 of Set 8 | san patricio
# Processing Record 2 of Set 8 | den helder
# Processing Record 3 of Set 8 | takoradi
# Processing Record 4 of Set 8 | nivala
# Processing Record 5 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 6 of Set 8 | parit buntar
# Processing Record 7 of Set 8 | waipawa
# Processing Record 8 of Set 8 | pritzwalk
# Processing Record 9 of Set 8 | provideniya
# Processing Record 10 of Set 8 | naraura
# Processing Record 11 of Set 8 | barra
# Processing Record 12 of Set 8 | pineville
# Processing Record 13 of Set 8 | mawlaik
# Processing Record 14 of Set 8 | iqaluit
# Processing Record 15 of Set 8 | pinega
# Processing Record 16 of Set 8 | ixtapa
# Processing Record 17 of Set 8 | bahia blanca
# Processing Record 18 of Set 8 | taveta
# Processing Record 19 of Set 8 | tarragona
# Processing Record 20 of Set 8 | erdenet
# Processing Record 21 of Set 8 | hatillo
# Processing Record 22 of Set 8 | brae
# Processing Record 23 of Set 8 | rawson
# Processing Record 24 of Set 8 | ust-nera
# Processing Record 25 of Set 8 | kaeo
# Processing Record 26 of Set 8 | yerbogachen
# Processing Record 27 of Set 8 | ulaangom
# Processing Record 28 of Set 8 | cockburn town
# Processing Record 29 of Set 8 | iquitos
# Processing Record 30 of Set 8 | luanda
# Processing Record 31 of Set 8 | lubao
# Processing Record 32 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 33 of Set 8 | sibu
# Processing Record 34 of Set 8 | lincoln
# Processing Record 35 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 8 | otane
# Processing Record 37 of Set 8 | tiksi
# Processing Record 38 of Set 8 | marsh harbour
# Processing Record 39 of Set 8 | havre-saint-pierre
# Processing Record 40 of Set 8 | ahuimanu
# Processing Record 41 of Set 8 | indramayu
# Processing Record 42 of Set 8 | kabo
# Processing Record 43 of Set 8 | isangel
# Processing Record 44 of Set 8 | temple terrace
# Processing Record 45 of Set 8 | palmer
# Processing Record 46 of Set 8 | chernaya kholunitsa
# Processing Record 47 of Set 8 | hobyo
# Processing Record 48 of Set 8 | hami
# Processing Record 49 of Set 8 | chifeng
# Processing Record 50 of Set 8 | umba
# Processing Record 1 of Set 9 | mandapam
# Processing Record 2 of Set 9 | kizilskoye
# Processing Record 3 of Set 9 | codrington
# Processing Record 4 of Set 9 | catamarca
# Processing Record 5 of Set 9 | shitanjing
# Processing Record 6 of Set 9 | ceuta
# Processing Record 7 of Set 9 | zhanakorgan
# Processing Record 8 of Set 9 | sechura
# Processing Record 9 of Set 9 | salalah
# Processing Record 10 of Set 9 | necochea
# Processing Record 11 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 12 of Set 9 | kattivakkam
# Processing Record 13 of Set 9 | kavieng
# Processing Record 14 of Set 9 | narasapur
# Processing Record 15 of Set 9 | arys
# Processing Record 16 of Set 9 | yarada
# Processing Record 17 of Set 9 | aykhal
# Processing Record 18 of Set 9 | nauta
# Processing Record 19 of Set 9 | airai
# Processing Record 20 of Set 9 | shahr-e kord
# Processing Record 21 of Set 9 | bac lieu
# Processing Record 22 of Set 9 | port-gentil
# Processing Record 23 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 9 | dalvik
# Processing Record 25 of Set 9 | sencur
# Processing Record 26 of Set 9 | viedma
# Processing Record 27 of Set 9 | beira
# Processing Record 28 of Set 9 | yayva
# Processing Record 29 of Set 9 | sydney mines
# Processing Record 30 of Set 9 | artigas
# Processing Record 31 of Set 9 | birao
# Processing Record 32 of Set 9 | luangwa
# Processing Record 33 of Set 9 | zhaotong
# Processing Record 34 of Set 9 | sung noen
# Processing Record 35 of Set 9 | mahudha
# Processing Record 36 of Set 9 | qasigiannguit
# Processing Record 37 of Set 9 | khandyga
# Processing Record 38 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 9 | bethel
# Processing Record 40 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 9 | hambantota
# Processing Record 42 of Set 9 | ojinaga
# Processing Record 43 of Set 9 | gazli
# Processing Record 44 of Set 9 | anloga
# Processing Record 45 of Set 9 | boulder
# Processing Record 46 of Set 9 | tunggol
# Processing Record 47 of Set 9 | tsiroanomandidy
# Processing Record 48 of Set 9 | constitucion
# Processing Record 49 of Set 9 | honningsvag
# Processing Record 50 of Set 9 | flinders
# Processing Record 1 of Set 10 | udachnyy
# Processing Record 2 of Set 10 | bathsheba
# Processing Record 3 of Set 10 | bilibino
# Processing Record 4 of Set 10 | oussouye
# Processing Record 5 of Set 10 | acarau
# Processing Record 6 of Set 10 | khash
# Processing Record 7 of Set 10 | lagoa
# Processing Record 8 of Set 10 | bennington
# Processing Record 9 of Set 10 | sayaxche
# Processing Record 10 of Set 10 | sulangan
# Processing Record 11 of Set 10 | banda aceh
# Processing Record 12 of Set 10 | mucurapo
# Processing Record 13 of Set 10 | rocha
# Processing Record 14 of Set 10 | kartaly
# Processing Record 15 of Set 10 | contamana
# Processing Record 16 of Set 10 | mchinji
# Processing Record 17 of Set 10 | terney
# Processing Record 18 of Set 10 | moose factory
# Processing Record 19 of Set 10 | archidona
# Processing Record 20 of Set 10 | sola
# Processing Record 21 of Set 10 | boddam
# Processing Record 22 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 23 of Set 10 | winnemucca
# Processing Record 24 of Set 10 | poum
# Processing Record 25 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 10 | san clemente
# Processing Record 27 of Set 10 | yerkoy
# Processing Record 28 of Set 10 | humberto de campos
# Processing Record 29 of Set 10 | bhanvad
# Processing Record 30 of Set 10 | northam
# Processing Record 31 of Set 10 | moroni
# Processing Record 32 of Set 10 | adrar
# Processing Record 33 of Set 10 | taksimo
# Processing Record 34 of Set 10 | wahpeton
# Processing Record 35 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 10 | magan
# Processing Record 37 of Set 10 | khani
# Processing Record 38 of Set 10 | mayo
# Processing Record 39 of Set 10 | katobu
# Processing Record 40 of Set 10 | swellendam
# Processing Record 41 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 42 of Set 10 | panzhihua
# Processing Record 43 of Set 10 | basco
# Processing Record 44 of Set 10 | sao joao da barra
# Processing Record 45 of Set 10 | dois corregos
# Processing Record 46 of Set 10 | los llanos de aridane
# Processing Record 47 of Set 10 | dzilam gonzalez
# Processing Record 48 of Set 10 | monte azul
# Processing Record 49 of Set 10 | caceres
# Processing Record 50 of Set 10 | ronneby
# Processing Record 1 of Set 11 | south sioux city
# Processing Record 2 of Set 11 | linxia
# Processing Record 3 of Set 11 | quelimane
# Processing Record 4 of Set 11 | telimele
# Processing Record 5 of Set 11 | balykshi
# City not found. Skipping...
# Processing Record 6 of Set 11 | odlabari
# Processing Record 7 of Set 11 | teguise
# Processing Record 8 of Set 11 | arnprior
# Processing Record 9 of Set 11 | lompoc
# Processing Record 10 of Set 11 | horsham
# Processing Record 11 of Set 11 | ust-kuyga
# Processing Record 12 of Set 11 | the pas
# Processing Record 13 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 11 | mudyuga
# City not found. Skipping...
# Processing Record 15 of Set 11 | singapore
# Processing Record 16 of Set 11 | camacha
# Processing Record 17 of Set 11 | hit
# Processing Record 18 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 11 | shimoda
# Processing Record 20 of Set 11 | ugoofaaru
# Processing Record 21 of Set 11 | iralaya
# Processing Record 22 of Set 11 | channapatna
# Processing Record 23 of Set 11 | port hawkesbury
# Processing Record 24 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 11 | whitehorse
# Processing Record 26 of Set 11 | altoona
# Processing Record 27 of Set 11 | locri
# Processing Record 28 of Set 11 | muvattupula
# Processing Record 29 of Set 11 | qarchi gak
# Processing Record 30 of Set 11 | cozumel
# Processing Record 31 of Set 11 | lata
# Processing Record 32 of Set 11 | hede
# Processing Record 33 of Set 11 | benghazi
# Processing Record 34 of Set 11 | boa vista
# Processing Record 35 of Set 11 | vicuna
# Processing Record 36 of Set 11 | kurumkan
# Processing Record 37 of Set 11 | bonthe
# Processing Record 38 of Set 11 | abilene
# Processing Record 39 of Set 11 | harper
# Processing Record 40 of Set 11 | saint anthony
# Processing Record 41 of Set 11 | morgan city
# Processing Record 42 of Set 11 | alyangula
# Processing Record 43 of Set 11 | polunochnoye
# Processing Record 44 of Set 11 | casablanca
# Processing Record 45 of Set 11 | pangkalanbuun
# Processing Record 46 of Set 11 | rawah
# Processing Record 47 of Set 11 | abha
# Processing Record 48 of Set 11 | prince rupert
# Processing Record 49 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 11 | george town
# Processing Record 1 of Set 12 | calabazar de sagua
# Processing Record 2 of Set 12 | kalispell
# Processing Record 3 of Set 12 | cap malheureux
# Processing Record 4 of Set 12 | guerrero negro
# Processing Record 5 of Set 12 | stornoway
# Processing Record 6 of Set 12 | denpasar
# Processing Record 7 of Set 12 | talnakh
# Processing Record 8 of Set 12 | alekseyevsk
# Processing Record 9 of Set 12 | lencois paulista
# Processing Record 10 of Set 12 | fomboni
# Processing Record 11 of Set 12 | garissa
# Processing Record 12 of Set 12 | bang saphan
# Processing Record 13 of Set 12 | souillac
# Processing Record 14 of Set 12 | mae sai
# Processing Record 15 of Set 12 | velyka kisnytsya
# City not found. Skipping...
# Processing Record 16 of Set 12 | ballina
# Processing Record 17 of Set 12 | altay
# Processing Record 18 of Set 12 | atar
# Processing Record 19 of Set 12 | lilongwe
# Processing Record 20 of Set 12 | port hedland
# Processing Record 21 of Set 12 | migori
# Processing Record 22 of Set 12 | salinas
# Processing Record 23 of Set 12 | high prairie
# Processing Record 24 of Set 12 | clyde river
# Processing Record 25 of Set 12 | eureka
# Processing Record 26 of Set 12 | at-bashi
# Processing Record 27 of Set 12 | fayetteville
# Processing Record 28 of Set 12 | hammerfest
# Processing Record 29 of Set 12 | te anau
# Processing Record 30 of Set 12 | eyrarbakki
# Processing Record 31 of Set 12 | healdsburg
# Processing Record 32 of Set 12 | sabha
# Processing Record 33 of Set 12 | palana
# Processing Record 34 of Set 12 | pemangkat
# Processing Record 35 of Set 12 | priego de cordoba
# Processing Record 36 of Set 12 | victor harbor
# Processing Record 37 of Set 12 | tuatapere
# Processing Record 38 of Set 12 | nanyang
# Processing Record 39 of Set 12 | puerto madero
# Processing Record 40 of Set 12 | tazovskiy
# Processing Record 41 of Set 12 | pointe michel
# Processing Record 42 of Set 12 | leningradskiy
# Processing Record 43 of Set 12 | englewood
# Processing Record 44 of Set 12 | doha
# Processing Record 45 of Set 12 | sao gabriel da cachoeira
# Processing Record 46 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 12 | nouadhibou
# Processing Record 48 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 12 | tonantins
# Processing Record 50 of Set 12 | manzanares
# Processing Record 1 of Set 13 | zapolyarnyy
# Processing Record 2 of Set 13 | oshakati
# Processing Record 3 of Set 13 | ishigaki
# Processing Record 4 of Set 13 | acapetahua
# Processing Record 5 of Set 13 | soe
# Processing Record 6 of Set 13 | bundaberg
# Processing Record 7 of Set 13 | port pirie
# Processing Record 8 of Set 13 | bowen
# Processing Record 9 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 13 | suez
# Processing Record 11 of Set 13 | mangan
# Processing Record 12 of Set 13 | kosa
# Processing Record 13 of Set 13 | jefferson city
# Processing Record 14 of Set 13 | mercedes
# Processing Record 15 of Set 13 | trincomalee
# Processing Record 16 of Set 13 | mackay
# Processing Record 17 of Set 13 | buraydah
# Processing Record 18 of Set 13 | hay river
# Processing Record 19 of Set 13 | kavaratti
# Processing Record 20 of Set 13 | kolondieba
# Processing Record 21 of Set 13 | luang prabang
# Processing Record 22 of Set 13 | bell ville
# Processing Record 23 of Set 13 | vadso
# Processing Record 24 of Set 13 | celestun
# Processing Record 25 of Set 13 | deep river
# Processing Record 26 of Set 13 | sabzevar
# Processing Record 27 of Set 13 | fukuyama
# Processing Record 28 of Set 13 | kabelvag
# Processing Record 29 of Set 13 | santiago
# Processing Record 30 of Set 13 | kathmandu
# Processing Record 31 of Set 13 | monrovia
# Processing Record 32 of Set 13 | burns lake
# Processing Record 33 of Set 13 | varnamo
# Processing Record 34 of Set 13 | saryg-sep
# Processing Record 35 of Set 13 | rio grande
# Processing Record 36 of Set 13 | the valley
# Processing Record 37 of Set 13 | tarata
# Processing Record 38 of Set 13 | wolmaranstad
# City not found. Skipping...
# Processing Record 39 of Set 13 | thibodaux
# Processing Record 40 of Set 13 | baykit
# Processing Record 41 of Set 13 | lidkoping
# Processing Record 42 of Set 13 | pontes e lacerda
# Processing Record 43 of Set 13 | grindavik
# Processing Record 44 of Set 13 | daitari
# Processing Record 45 of Set 13 | kuldur
# Processing Record 46 of Set 13 | qaqortoq
# Processing Record 47 of Set 13 | ferme-neuve
# Processing Record 48 of Set 13 | karakulino
# Processing Record 49 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 13 | skibbereen
# Processing Record 1 of Set 14 | trinidad
# Processing Record 2 of Set 14 | iroquois falls
# Processing Record 3 of Set 14 | gravelbourg
# Processing Record 4 of Set 14 | hrebinka
# Processing Record 5 of Set 14 | terrace
# Processing Record 6 of Set 14 | thunder bay
# Processing Record 7 of Set 14 | miraflores
# Processing Record 8 of Set 14 | ndende
# Processing Record 9 of Set 14 | gat
# Processing Record 10 of Set 14 | kanniyakumari
# Processing Record 11 of Set 14 | berlevag
# Processing Record 12 of Set 14 | magdug
# Processing Record 13 of Set 14 | luba
# Processing Record 14 of Set 14 | zhangye
# Processing Record 15 of Set 14 | kuhdasht
# Processing Record 16 of Set 14 | leeton
# Processing Record 17 of Set 14 | jackson
# Processing Record 18 of Set 14 | surin
# Processing Record 19 of Set 14 | sedlcany
# Processing Record 20 of Set 14 | sooke
# Processing Record 21 of Set 14 | shache
# Processing Record 22 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 23 of Set 14 | banjar
# Processing Record 24 of Set 14 | abu kamal
# Processing Record 25 of Set 14 | filingue
# Processing Record 26 of Set 14 | novobureyskiy
# Processing Record 27 of Set 14 | charters towers
# Processing Record 28 of Set 14 | kalmunai
# Processing Record 29 of Set 14 | thinadhoo
# Processing Record 30 of Set 14 | lokeren
# Processing Record 31 of Set 14 | cap-aux-meules
# Processing Record 32 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 14 | huarmey
# Processing Record 34 of Set 14 | deputatskiy
# Processing Record 35 of Set 14 | morondava
# Processing Record 36 of Set 14 | sibolga
# Processing Record 37 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 14 | metro
# Processing Record 39 of Set 14 | srednekolymsk
# Processing Record 40 of Set 14 | granville
# Processing Record 41 of Set 14 | saint-georges
# Processing Record 42 of Set 14 | yorkton
# Processing Record 43 of Set 14 | melissourgoi
# City not found. Skipping...
# Processing Record 44 of Set 14 | popondetta
# Processing Record 45 of Set 14 | mogzon
# Processing Record 46 of Set 14 | fuyu
# Processing Record 47 of Set 14 | tuckahoe
# Processing Record 48 of Set 14 | sobolevo
# Processing Record 49 of Set 14 | ipameri
# Processing Record 50 of Set 14 | windhoek
# Processing Record 1 of Set 15 | sorong
# Processing Record 2 of Set 15 | missoula
# Processing Record 3 of Set 15 | new york
# Processing Record 4 of Set 15 | ulaanbaatar
# Processing Record 5 of Set 15 | margate
# Processing Record 6 of Set 15 | miquelon
# Processing Record 7 of Set 15 | san cristobal
# Processing Record 8 of Set 15 | wanaka
# Processing Record 9 of Set 15 | guozhen
# Processing Record 10 of Set 15 | matara
# Processing Record 11 of Set 15 | chapais
# Processing Record 12 of Set 15 | bereda
# Processing Record 13 of Set 15 | kalianget
# Processing Record 14 of Set 15 | santa
# Processing Record 15 of Set 15 | macheng
# Processing Record 16 of Set 15 | dubbo
# Processing Record 17 of Set 15 | manali
# Processing Record 18 of Set 15 | kruisfontein
# Processing Record 19 of Set 15 | queenstown
# Processing Record 20 of Set 15 | tashtyp
# Processing Record 21 of Set 15 | krosno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hermanus      ZA -34.42   19.23     54.00        56          82
# 1            Tigzirt      DZ  36.89    4.12     86.36        46           0
# 2             Barrow      US  71.29 -156.79     37.40        90          90
# 3             Atuona      PF  -9.80 -139.03     78.21        80          16
# 4           Meulaboh      ID   4.14   96.13     80.46        78         100
# 5               Nome      US  64.50 -165.41     54.00        81          90
# 6  Zheleznodorozhnyy      RU  55.75   38.00     66.20        59          56
# 7       Port Lincoln      AU -34.73  135.87     57.99        81          91
# 8           Klaksvik      FO  62.23   -6.59     51.80        76          75
# 9              Korla      CN  41.76   86.15     72.00        81           0
#
#    Wind Speed Current Description
# 0        5.01       broken clouds
# 1       10.36           clear sky
# 2       19.46     overcast clouds
# 3       19.66          light rain
# 4        2.28          light rain
# 5        5.82     overcast clouds
# 6        6.71       broken clouds
# 7       16.67     overcast clouds
# 8        6.93       broken clouds
# 9        5.99           clear sky

# %%
# Export the DataFrame as a CSV
output_data_file = "WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file)
